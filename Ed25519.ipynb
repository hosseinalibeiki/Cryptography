# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in c:\users\asus\anaconda3\envs\generativeai\lib\site-packages (43.0.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\asus\anaconda3\envs\generativeai\lib\site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\envs\generativeai\lib\site-packages (from cffi>=1.12->cryptography) (2.22)

# %%
from cryptography.hazmat.primitives.asymmetric import ed25519

# %%
from cryptography.hazmat.primitives import serialization

# %%
# ----------------------------
# 1️⃣ Generate Key Pair
# ----------------------------

# %%
private_key = ed25519.Ed25519PrivateKey.generate()
public_key = private_key.public_key()

# %%
private_bytes = private_key.private_bytes(
    encoding=serialization.Encoding.Raw,
    format=serialization.PrivateFormat.Raw,
    encryption_algorithm=serialization.NoEncryption()
)

# %%
public_bytes = public_key.public_bytes(
    encoding=serialization.Encoding.Raw,
    format=serialization.PublicFormat.Raw
)

# %%
print("Private Key:", private_bytes.hex())
# Out:
# Private Key: c951676e901218387a8d6a9cae3ac7a86e3fd573a202bd548427b08468e3db64

# %%
print("Public Key :", public_bytes.hex())
# Out:
# Public Key : ef60944f7f02400d648b0879d8e1f45c751a939c1e557fc7ba2d276e3f8446a0

# %%
message = b"TicketID:12345|Event:Concert2025|Seat:A12"

# %%
signature = private_key.sign(message)

# %%
print("Signature:", signature.hex())
# Out:
# Signature: 99deec54ea3db0df45f32fb8099e96d8d86f06a04c241c7e60d8e1251faf64093aa402af0aa28e1eeb1d8acf4e7a2452b614abc3077602d2f020d1becefe1b0c

# %%
len(signature)
# Out:
# 64

# %%
try:
    public_key.verify(signature, message)
    print("Signature is valid.")
except Exception:
    print("Signature is INVALID.")
# Out:
# Signature is valid.
